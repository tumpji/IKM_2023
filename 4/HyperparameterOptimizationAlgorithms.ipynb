# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Grid-Search" data-toc-modified-id="Grid-Search-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Grid Search</a></span></li><li><span><a href="#Random-Search" data-toc-modified-id="Random-Search-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Random Search</a></span></li><li><span><a href="#CMA-ES" data-toc-modified-id="CMA-ES-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>CMA-ES</a></span></li><li><span><a href="#Quasi-Monte-Carlo" data-toc-modified-id="Quasi-Monte-Carlo-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Quasi Monte Carlo</a></span></li><li><span><a href="#Tree-structured-Parzen" data-toc-modified-id="Tree-structured-Parzen-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Tree-structured Parzen</a></span></li></ul></div>

# %%
# %matplotlib widget
import numpy as np
import matplotlib.pyplot as plt

import matplotlib

import optuna
optuna.logging.disable_default_handler()

from test_functions import *

from interactive_plots import InteractivePlot, RandomPlot

# %%
show_functions()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Black-Box Optimization Algorithms
# ### Grid Search

# %%
InteractivePlot('results/gridsearch.npz')
# Out:
# interactive(children=(IntSlider(value=0, description='function_id', max=3), IntSlider(value=4, description='nu…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Random Search

# %%
InteractivePlot('results/randomsearch.npz')
# Out:
# interactive(children=(IntSlider(value=0, description='function_id', max=3), IntSlider(value=1, description='nu…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
RandomPlot('results/ff_randomsearch.npz')
# Out:
# interactive(children=(IntSlider(value=0, description='function_id', max=3), IntSlider(value=1, description='nu…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### CMA-ES

# %%
InteractivePlot('results/cmaessearch.npz')
# Out:
# interactive(children=(IntSlider(value=0, description='function_id', max=3), IntSlider(value=1, description='nu…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
RandomPlot('results/ff_cmaessearch.npz')
# Out:
# interactive(children=(IntSlider(value=0, description='function_id', max=3), IntSlider(value=1, description='nu…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Quasi Monte Carlo

# %%
InteractivePlot('results/quasimontecarlosearch.npz')
# Out:
# interactive(children=(IntSlider(value=0, description='function_id', max=3), IntSlider(value=1, description='nu…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
RandomPlot('results/ff_quasimontecarlosearch.npz')
# Out:
# interactive(children=(IntSlider(value=0, description='function_id', max=3), IntSlider(value=1, description='nu…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Tree-structured Parzen

# %%
InteractivePlot('results/treestructuredparzensearch.npz')
# Out:
# interactive(children=(IntSlider(value=0, description='function_id', max=3), IntSlider(value=1, description='nu…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
RandomPlot('results/ff_treestructuredparzensearch.npz')
# Out:
# interactive(children=(IntSlider(value=0, description='function_id', max=3), IntSlider(value=1, description='nu…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Gaussian Process

# %%
InteractivePlot('results/gaussianprocesssearch.npz')
# Out:
# interactive(children=(IntSlider(value=0, description='function_id', max=3), IntSlider(value=1, description='nu…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
RandomPlot('results/gaussianprocesssearch.npz')
# Out:
# interactive(children=(IntSlider(value=0, description='function_id', max=3), IntSlider(value=1, description='nu…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
